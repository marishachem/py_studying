# %%
from sympy import *
from sympy.plotting import plot
init_printing(use_unicode=False, wrap_line=False, no_global=True)
x, y, z, f1, f2,f3,f4,f5, f6 = symbols('x y z f1 f2 f3 f4 f5 f6')

# %%
init_printing(use_unicode=False, wrap_line=False, no_global=True)

# %%
x**2/2
# Out:
#  2
# x
# --
# 2

# %%
for word in ['Hello','World']:
    print(word)
# Out:
# Hello
# World

# %%
sympy.init_printing()

# %%
polynomial = (2*x + 3)**4

# %%
polynomial.expand()
# Out:
#     4       3        2
# 16⋅x  + 96⋅x  + 216⋅x  + 216⋅x + 81

# %%
polynomial
# Out:
#          4
# (2⋅x + 3)

# %%
polynomial.integrate(x)
# Out:
#     5
# 16⋅x        4       3        2
# ───── + 24⋅x  + 72⋅x  + 108⋅x  + 81⋅x
#   5

# %%
polynomial.diff(x, 2)
# Out:
#             2
# 48⋅(2⋅x + 3)

# %%
y=Symbol('y')
y
# Out:
# y

# %%
expression=(x**2-y**2)/(x**2+2*x*y+y**2)
expression
# Out:
#      2    2
#     x  - y
# ───────────────
#  2            2
# x  + 2⋅x⋅y + y

# %%
simplify(expression)
# Out:
# x - y
# ─────
# x + y

# %%
m=Symbol('m')
m
# Out:
# m

# %%
expression=((10*m**2)/(3+2*m)-5*m)/((30*m**2-15*m)/(8*m**3+27))
expression
# Out:
#             ⎛     2       ⎞
# ⎛   3     ⎞ ⎜ 10⋅m        ⎟
# ⎝8⋅m  + 27⎠⋅⎜─────── - 5⋅m⎟
#             ⎝2⋅m + 3      ⎠
# ───────────────────────────
#             2
#         30⋅m  - 15⋅m

# %%
simplify(expression)
# Out:
#      2
# - 4⋅m  + 6⋅m - 9
# ────────────────
#     2⋅m - 1

# %%
expression=(2*x+3*y)**2-3*x*(4*x/3+4*y)
expression
# Out:
#       ⎛4⋅x      ⎞              2
# - 3⋅x⋅⎜─── + 4⋅y⎟ + (2⋅x + 3⋅y)
#       ⎝ 3       ⎠

# %%
simplify(expression)
# Out:
#    2
# 9⋅y

# %%
expression=28*x*y+(2*x-7*y)**2
expression
# Out:
#                     2
# 28⋅x⋅y + (2⋅x - 7⋅y)

# %%
simplify(expression)
# Out:
#    2       2
# 4⋅x  + 49⋅y

# %%
expression=(x/2+x/5)*1/x**2
expression
# Out:
#  7
# ────
# 10⋅x

# %%
expression=(x-6*x/(x+2))*((x+2)/(x-4))
expression
# Out:
#         ⎛     6⋅x ⎞
# (x + 2)⋅⎜x - ─────⎟
#         ⎝    x + 2⎠
# ───────────────────
#        x - 4

# %%
simplify(expression)
# Out:
# x

# %%
a=Symbol('a')
a
# Out:
# a

# %%
b=Symbol('b')
b
# Out:
# b

# %%
expression=(4/a**2+9/b**2)*(a*b)**2
expression
# Out:
#  2  2 ⎛9    4 ⎞
# a ⋅b ⋅⎜── + ──⎟
#       ⎜ 2    2⎟
#       ⎝b    a ⎠

# %%
simplify(expression)
# Out:
#    2      2
# 9⋅a  + 4⋅b

# %%
c=Symbol('c')
c
# Out:
# c

# %%
k=Symbol('k')

# %%
z=((5/(c*k**2)*k**3*c)-((10*k+1)/2))

# %%
simplify(z)
# Out:
# -1/2

# %%
sqrt(4)
# Out:
# 2

# %%
ex=(sqrt(13)+sqrt(7))**2/(10+sqrt(91))
ex
# Out:
#           2
# (√7 + √13)
# ───────────
#   √91 + 10

# %%
simplify(ex)
# Out:
# 2

# %%
sympy.log(100,2)
# Out:
#     log(25)
# 2 + ───────
#      log(2)

# %%
gfg = log(16, 2) 
gfg
# Out:
# 4

# %%
ex=log((10/b**3),10)
ex
# Out:
#    ⎛10⎞
# log⎜──⎟
#    ⎜ 3⎟
#    ⎝b ⎠
# ───────
# log(10)

# %%
simplify(ex)
# Out:
#    ⎛10⎞
# log⎜──⎟
#    ⎜ 3⎟
#    ⎝b ⎠
# ───────
# log(10)

# %%
ex=log(10,10)-log(b**3)
ex
# Out:
#        ⎛ 3⎞
# 1 - log⎝b ⎠

# %%
import numpy as np
from math import e
ln = np.log
ln(e)
# Out:
# 1.0

# %%
log(e)
# Out:
# 1.00000000000000

# %%
x=symbols('x')
f= x + 1
f
# Out:
# x + 1

# %%
plot(f)

# %%
f1=-3*x+5
f1
# Out:
# 5 - 3⋅x

# %%
plot(f1)

# %%
print(f1.subs(x,2))
# Out:
# -1

# %%
f2=5-3*(5/3)

# %%
plot(f2)
print(f2.subs(x,5/3),'\n',f2.subs(x,2))
# Out:
# 0
#  -1

# %%
f3=3*(x**2)+3*x-6
f3
# Out:
#    2
# 3⋅x  + 3⋅x - 6

# %%
plot(f3)
print(f3.subs(x,0.5), f3.subs(x,7))
# Out:
# -3.75000000000000 162

# %%
f4=2*(x**4)+x**3-6*(x**2)+7*x+1
f4
# Out:
#    4    3      2
# 2⋅x  + x  - 6⋅x  + 7⋅x + 1

# %%
plot(f4)
print(f4.subs(x,3), f4.subs(x,-5))
# Out:
# 157 941

# %%
f5=(x**2)**x
f5
# Out:
#     x
# ⎛ 2⎞
# ⎝x ⎠

# %%
plot(f5)
print(f5.subs(x,0), f5.subs(x,10))
# Out:
# 1 100000000000000000000

# %%
# Out:
# 1

# %%
f5=5**(x)
f5
# Out:
#  x
# 5

# %%
plot(f5)

# %%
line_func=k*x+b
interactive_plot=interactive(line_func, k=(-5,5,0.1), b=(-5,5,0.1))
output = interactive_plot.children[-1]
output.layout.height = '350px'
interactive_plot
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-193-8dfe8a4ec56c> in <module>
#       1 line_func=k*x+b
# ----> 2 interactive_plot=interactive(line_func, k=(-5,5,0.1), b=(-5,5,0.1))
#       3 output = interactive_plot.children[-1]
#       4 output.layout.height = '350px'
#       5 interactive_plot
#
# TypeError: 'module' object is not callable

# %%
f = exp(x)
f
plot(f)

# %%
f1 = 100*ln(x)
f1
plot(f1)

# %%
f2 = 2*x**2+3*x-5
f2
plot(f2)

# %%
f3=5*x**2-8
f3
plot(f3)

# %%
f4=sqrt(x)
f4
plot(f4)

# %%
from sympy import *
from sympy.plotting import plot

# %%
init_printing(use_unicode=False, wrap_line=False, no_global=True)

# %%
x,y,z = symbols('x y z')

# %%
f = x**2
f
# Out:
#  2
# x

# %%
plot(f)
print(f.subs(x,100), f.subs(x,-100))
# Out:
# 10000 10000

# %%
f2 = 2*x**2 + 10*x +2
f2
plot(f2)
print(f2.subs(x,100), f.subs(x,-100))
# Out:
# 21002 10000

# %%
f3 = -2*x**2 + 10*x - 12
plot(f3)

# %%
f4 = -2*x**2 + 10*x + 100
plot(f4)

# %%
f5 = sqrt(x)
f5
# Out:
#   ___
# \/ x

# %%
plot(f5)

# %%
f5.subs(x,-1)
# Out:
# I

# %%
plot(f5,(x,0,100))

# %%
f6 = exp(x) - 10000
f6
plot(f6)

# %%
#задание после 3 части
f1=5*x+1.5
f1
# подставить значение -10 и +10 для определения четности/нечетности
f1.subs(x,10)
# Out:
# 51.5000000000000

# %%
f1.subs(x,-10)
# Out:
# -48.5000000000000

# %%
solve(f1) # нули функции
# Out:
# [-0.3]

# %%
solve_univariate_inequality(f1>0,x) #промежутки >0 и <0
# Out:
# And(-0.3 < x, x < oo)

# %%
solve_univariate_inequality(f1<0,x)
# Out:
# And(-oo < x, x < -0.3)

# %%
plot(f1)

# %%
f2=2*exp(x*0.2)-1
f2
# Out:
#    0.2*x
# 2*e      - 1

# %%
f2.subs(x,10)
# Out:
# 13.7781121978613

# %%
f2.subs(x,-10)
# Out:
# -0.729329433526775

# %%
solve(f2)
# Out:
# [-3.46573590279973]

# %%
solve_univariate_inequality(f2>0,x)
# Out:
# And(x < oo, -5.0*log(2) < x)

# %%
solve_univariate_inequality(f2<0,x)
# Out:
# And(-oo < x, x < -5.0*log(2))

# %%
plot(f2)

# %%
f3=3*sqrt(x)-15
f3
f3.subs(x,10)
# Out:
#           ____
# -15 + 3*\/ 10

# %%
f3
# Out:
#     ___
# 3*\/ x  - 15

# %%
solve(f3)
# Out:
# [25]

# %%
plot(f3)

# %%
f3.subs(x,2)
# Out:
#           ___
# -15 + 3*\/ 2

# %%
f4=2*log(x)+5
f4
# Out:
# 2*log(x) + 5

# %%
f4.subs(x,10)
# Out:
# 2*log(10) + 5

# %%
solve(f4)
# Out:
#   -5/2
# [e    ]

# %%
plot(f4)

# %%
f5=-5*x**2-10*x+100
f5
# Out:
#      2
# - 5*x  - 10*x + 100

# %%
f5.subs(x,10)
# Out:
# -500

# %%
f5.subs(x,-10)
# Out:
# -300

# %%
solve(f5)
# Out:
#         ____      ____
# [-1 + \/ 21 , - \/ 21  - 1]

# %%
solve_univariate_inequality(f5>0,x)
# Out:
#    /           ____      ____        \
# And\x < -1 + \/ 21 , - \/ 21  - 1 < x/

# %%
solve_univariate_inequality(f5<0,x)
# Out:
#   /   /                 ____    \     /               ____    \\
# Or\And\-oo < x, x < - \/ 21  - 1/, And\x < oo, -1 + \/ 21  < x//

# %%
plot(f5)

# %%
#4.4

# %%
# %matplotlib inline
from ipywidgets import interactive
import matplotlib.pyplot as plt
import numpy as np

# %%
def get_polyfunc_title(koefs):
    s_koefs = ''.join([f'+{koefs[i]}x^{len(koefs)-i-1}' if koefs[i]>0 
                       else f'{koefs[i]}x^{len(koefs)-i-1}' if koefs[i]<0 
                       else ''
                       for i in range(len(koefs))])
    expr = s_koefs.replace('x^0', '') \
                  .replace('+', ' + ') \
                  .replace('-', ' - ') \
                  .replace('x^1', 'x') \
                  .replace(' 1x', ' x')

    if expr[:3]==' + ':
        expr = expr[3:]
    if expr:
        return '$f(x) = ' + expr + '$'
    
def check(f, x, y):
    check = False not in [f(x[i])==y[i] for i in range(len(x))]
    if not check:
        print('Пока не получилось')
    else:
        print('Ура! Получилось!')

# %%
def parabola(a, b, c):
    plt.figure(3)
    plt.axhline(0, color='black')
    plt.axvline(0, color='black')

    x, y = [x for x, y in points], [y for x, y in points]
    plt.scatter(x, y, c='r')


    
    if a != 0:
        f = lambda x: a * x**2 + b * x + c
        check(f, x, y)
        
        x = np.linspace(-15, 15, num=1000)
        plt.plot(x, a * x**2 + b * x + c)
    
    plt.ylim(-35, 35)
    plt.xlim(-10, 10)
        
    plt.title(get_polyfunc_title([a,b,c]))
    plt.show()

# %%
points = [[-2.5, 15.0], 
          [-2, 10], 
          [-1.5, 7.0], 
          [-1, 6], 
          [-0.5, 7.0], 
          [0, 10], 
          [0.5, 15.0], 
          [1, 22], 
          [1.5, 31.0]]

interactive_plot = interactive(parabola, a=(-5, 5, 1), b=(-100, 100, 1), c=(-20, 20, 1))
output = interactive_plot.children[-1]
output.layout.height = '300px'
interactive_plot
# Out:
# interactive(children=(IntSlider(value=0, description='a', max=5, min=-5), IntSlider(value=0, description='b', …

# %%
points = [[-5.0, -68.0], 
          [-3.75, -42.375], 
          [-2.5, -23.0], 
          [-1.25, -9.875], 
          [0.0, -3.0], 
          [1.25, -2.375], 
          [2.5, -8.0], 
          [3.75, -19.875], 
          [5.0, -38.0]]

interactive_plot = interactive(parabola, a=(-5, 5, 1), b=(-100, 100, 1), c=(-20, 20, 1))
output = interactive_plot.children[-1]
output.layout.height = '300px'
interactive_plot
# Out:
# interactive(children=(IntSlider(value=0, description='a', max=5, min=-5), IntSlider(value=0, description='b', …

# %%
# -*- coding: utf-8 -*-
"""Свойства коэффициентов квадратичной функции. Решение практики.ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1-XQXDQOEg8KA8pLkjOsu2XjqknbTrtmI

## Свойства коэффициентов квадратичной функции. Решение практики

В качестве практики подберите, варьируя коэффициенты, квадратичную функцию для набора точек. Другими словами, вам нужно решить задачу интерполяции полиномом второй степени. Ниже вы найдете код, который создает ползунки, с помощью которых можно варьировать коэффициенты a, b и c, подбирая нужный вид параболы, а также рисует набор точек. <br><br>
Программа будет печатать над графиком актуальный вид функции и сама скажет вам, когда вы достигнете цели.
"""

# Commented out IPython magic to ensure Python compatibility.
# %matplotlib inline
from ipywidgets import interactive
import matplotlib.pyplot as plt
import numpy as np

def get_polyfunc_title(koefs):
    s_koefs = ''.join([f'+{koefs[i]}x^{len(koefs)-i-1}' if koefs[i]>0 
                       else f'{koefs[i]}x^{len(koefs)-i-1}' if koefs[i]<0 
                       else ''
                       for i in range(len(koefs))])
    expr = s_koefs.replace('x^0', '') \
                  .replace('+', ' + ') \
                  .replace('-', ' - ') \
                  .replace('x^1', 'x') \
                  .replace(' 1x', ' x')

    if expr[:3]==' + ':
        expr = expr[3:]
    if expr:
        return '$f(x) = ' + expr + '$'
    
def check(f, x, y):
    check = False not in [f(x[i])==y[i] for i in range(len(x))]
    if not check:
        print('Пока не получилось')
    else:
        print('Ура! Получилось!')

def parabola(a, b, c):
    plt.figure(3)
    plt.axhline(0, color='black')
    plt.axvline(0, color='black')

    x, y = [x for x, y in points], [y for x, y in points]
    plt.scatter(x, y, c='r')


    
    if a != 0:
        f = lambda x: a * x**2 + b * x + c
        check(f, x, y)
        
        x = np.linspace(-15, 15, num=1000)
        plt.plot(x, a * x**2 + b * x + c)
    
    plt.ylim(-35, 35)
    plt.xlim(-10, 10)
        
    plt.title(get_polyfunc_title([a,b,c]))
    plt.show()

points = [[-2.5, 15.0], 
          [-2, 10], 
          [-1.5, 7.0], 
          [-1, 6], 
          [-0.5, 7.0], 
          [0, 10], 
          [0.5, 15.0], 
          [1, 22], 
          [1.5, 31.0]]

interactive_plot = interactive(parabola, a=(-5, 5, 1), b=(-100, 100, 1), c=(-20, 20, 1))
output = interactive_plot.children[-1]
output.layout.height = '300px'
interactive_plot
# Out:
# interactive(children=(IntSlider(value=0, description='a', max=5, min=-5), IntSlider(value=0, description='b', …

# %%
#4.6

# %%
# -*- coding: utf-8 -*-
"""Свойства коэффициентов кубической функции. Практика.ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/18UMvRahP18I0gjbACcae6eiypxULx5O3

## Свойства коэффициентов кубической функции. Практика

В качестве практики подберите, как и в прошлый раз, варьируя коэффициенты, функцию для набора точек. Только в этот раз функция будет кубическая. Получается, вам нужно решить задачу интерполяции полиномом третьей степени. Интерфейс для выполнения задания аналогичен тому, который был в практике к предыдущему уроку.
"""

# Commented out IPython magic to ensure Python compatibility.
# %matplotlib inline
from ipywidgets import interactive
import matplotlib.pyplot as plt
import numpy as np

def get_polyfunc_title(koefs):
    s_koefs = ''.join([f'+{koefs[i]}x^{len(koefs)-i-1}' if koefs[i]>0 
                       else f'{koefs[i]}x^{len(koefs)-i-1}' if koefs[i]<0 
                       else ''
                       for i in range(len(koefs))])
    expr = s_koefs.replace('x^0', '') \
                  .replace('+', ' + ') \
                  .replace('-', ' - ') \
                  .replace('x^1', 'x') \
                  .replace(' 1x', ' x')

    if expr[:3]==' + ':
        expr = expr[3:]
    if expr:
        return '$f(x) = ' + expr + '$'
    
def check(f, x, y):
    check = False not in [f(x[i])==y[i] for i in range(len(x))]
    if not check:
        print('Пока не получилось')
    else:
        print('Ура! Получилось!')

def cubic_parabola(a, b, c, d):
    plt.figure(3)
    plt.axhline(0, color='black')
    plt.axvline(0, color='black')

    x, y = [x for x, y in points], [y for x, y in points]
    plt.scatter(x, y, c='r')
    
    if a!=0:
        f = lambda x: a * x**3 + b * x**2 + c * x + d
        check(f, x, y)
        
        x = np.linspace(-15, 15, num=1000)
        plt.plot(x, a * x**3 + b * x**2 + c * x + d)
        
    plt.ylim(-35, 35)
    plt.xlim(-5, 5)
    
    plt.title(get_polyfunc_title([a,b,c,d]))
    
    plt.show()

points = [[-0.5, -15.0],
          [-1, -31],
          [0, -7],
          [0.5, -4.0],
          [1, -3],
          [2, 5],
          [2.5, 18.0],
          [3, 41]]

interactive_plot = interactive(cubic_parabola, a=(-15, 15, 1), b=(-10, 10, 1), c=(-10, 10, 1), d=(-10, 10, 1))
output = interactive_plot.children[-1]
output.layout.height = '300px'
interactive_plot
# Out:
# interactive(children=(IntSlider(value=0, description='a', max=15, min=-15), IntSlider(value=0, description='b'…

# %%
points = [[-5.0, -68.0],
          [-3.75, -8.234375],
          [-2.5, 16.375],
          [-1.25, 17.546875],
          [0.0, 7.0],
          [1.25, -3.546875],
          [2.5, -2.375],
          [3.75, 22.234375],
          [5.0, 82.0]]

interactive_plot = interactive(cubic_parabola, a=(-15, 15, 1), b=(-10, 10, 1), c=(-10, 10, 1), d=(-10, 10, 1))
output = interactive_plot.children[-1]
output.layout.height = '300px'
interactive_plot
# Out:
# interactive(children=(IntSlider(value=0, description='a', max=15, min=-15), IntSlider(value=0, description='b'…

# %%
#4.8
from sympy import *
from sympy.plotting import plot
init_printing(use_unicode=False, wrap_line=False,no_global=True)
a1, a2, a0 = symbols('a1, a2, a0')
eq1_lp=a2-a1+a0+1
eq2_lp=4*a2+2*a1+a0-8
eq3_lp=4*a2-2*a1+a0+8

# %% [markdown]
# #находим коэф-ты по 3м точкам

# %%
nonlinsolve([eq1_lp, eq2_lp,eq3_lp], [a2,a1,a0])
# Out:
# {(-1, 4, 4)}

# %%
x=Symbol('x')
f=-x**2+4*x+4
f
# Out:
#    2
# - x  + 4*x + 4

# %%
f.subs(x,-2)
# Out:
# -8

# %%
import numpy as np
import matplotlib.pyplot as plt

x_range = np.linspace(-3,7, num=100)
f= lambda x: -x**2+4*x+4
plt.scatter([-1,2,-2],[-1,8,-8],c='r')
plt.axhline(0, color='black')
plt.axvline(0,color='black')
plt.plot(x_range,f(x_range))

# %%
#4.8 Hw
from sympy import *
from sympy.plotting import plot
init_printing(use_unicode=False, wrap_line=False,no_global=True)
a1, a2, a0 = symbols('a1, a2, a0')
eq1_lp=6.25*a2 - 2.5*a1 + a0 - 15
eq2_lp=4*a2 - 2*a1 + a0 - 10
eq3_lp=2.25*a2-1.5*a1+a0 - 7

# %%
nonlinsolve([eq1_lp, eq2_lp,eq3_lp], [a2,a1,a0])
# Out:
# {(4.0, 8.00000000000002, 10.0)}

# %%
f=4*x**2+8*x+10
f
# Out:
#    2
# 4*x  + 8*x + 10

# %%
f.subs(x,-2.5)
# Out:
# 15.0000000000000

# %%
import numpy as np
import matplotlib.pyplot as plt

x_range = np.linspace(-3,7, num=100)
f= lambda x: 4*x**2+8*x+10
plt.scatter([-2.5,-2,-1.5],[15,10,7],c='r')
plt.axhline(0, color='black')
plt.axvline(0,color='black')
plt.plot(x_range,f(x_range))

# %%
#4.8 Hw
from sympy import *
from sympy.plotting import plot
init_printing(use_unicode=False, wrap_line=False,no_global=True)
a3, a1, a2, a0 = symbols('a1, a2, a0, a3')
eq1_lp=-0.125*a3 + 0.25*a2 - 0.5*a1 + a0 + 15
eq2_lp=-a3 + a2 - a1 + a0 + 31
eq3_lp=a0 + 7
eq4_lp=0.125*a3 + 0.25*a2 + 0.5*a1+a0 + 4

# %%
nonlinsolve([eq1_lp, eq2_lp, eq3_lp, eq4_lp], [a3,a2,a1,a0])
# Out:
# {(4.0, -10.0, 10.0, -7.0)}

# %%
f=4*x**3-10*x**2+10*x - 7
f
# Out:
#    3       2
# 4*x  - 10*x  + 10*x - 7

# %%
f.subs(x,-0.5)
# Out:
# -15.0000000000000

# %%
import numpy as np
import matplotlib.pyplot as plt

x_range = np.linspace(-3,7, num=100)
f= lambda x: 4*x**3-10*x**2+10*x - 7
plt.scatter([-0.5,-1,0,0.5],[-15,-31,-7,-4],c='r')
plt.axhline(0, color='black')
plt.axvline(0,color='black')
plt.plot(x_range,f(x_range))

# %% [markdown]
# # 4.11 Hw

# %%
from sympy import *
from sympy.plotting import plot
init_printing(use_unicode=False, wrap_line=False,no_global=True)
a5 ,a4, a3, a1, a2, a0 = symbols('a1, a2, a0, a3, a4, a5')
eq1_lp= 23.4256*a4 - 10.648*a3 + 4.84*a2 - 2.2*a1 + a0 - 2
eq2_lp=a4 - a3 + a2 - a1 + a0 - 1
eq3_lp=a0 
eq4_lp=a4 + a3 + a2 + a1 + a0 - 1
eq5_lp=16*a4 + 8*a3 + 4*a2 + 2*a1 + a0 - 2

# %%
nonlinsolve([eq1_lp, eq2_lp, eq3_lp, eq4_lp, eq5_lp], [a4,a3,a2,a1,a0])
# Out:
# {(-0.159406565656566, -0.014520202020202, 1.15940656565657, 0.014520202020202, 0)}

# %%
f= (-0.159406565656566)*x**4 - 0.014520202020202*x**3 + 1.15940656565657*x**2 + 0.014520202020202*x
f
# Out:
#                      4                      3                     2
# - 0.159406565656566*x  - 0.014520202020202*x  + 1.15940656565657*x  + 0.014520202020202*x

# %%
f.subs(x,-1)
# Out:
# 1.00000000000000

# %%
f.subs(x,-2.2)
# Out:
# 2.00000000000001

# %%
f.subs(x,0)
# Out:
# 0

# %%
f.subs(x,1)
# Out:
# 1.00000000000000

# %%
f.subs(x,2)
# Out:
# 2.00000000000001

# %%
f.subs(x,10)
# Out:
# -1492.50000000000

# %%
f.subs(x,-10)
# Out:
# -1463.75000000000

# %%
import numpy as np
import matplotlib.pyplot as plt

x_range = np.linspace(-5,5, num=100)
f= lambda x: (-0.159406565656566)*x**4 - 0.014520202020202*x**3 + 1.15940656565657*x**2 + 0.014520202020202*x
plt.scatter([-2,-1,0,1,2],[2,1,0,1,2],c='r')
plt.axhline(0, color='black')
plt.axvline(0,color='black')
plt.plot(x_range,f(x_range))

# %%
f= (-0.159406565656566)*x**4 - 0.014520202020202*x**3 + 1.15940656565657*x**2 + 0.014520202020202*x

solve_univariate_inequality(f>0,x)
# Out:
# Or(And(-2.73665153048207 < x, x < -0.0125221286700732), And(0 < x, x < 2.65808455024125))

# %%
solve_univariate_inequality(f<0,x)
# Out:
# Or(And(-oo < x, x < -2.73665153048207), And(-0.0125221286700732 < x, x < 0), And(2.65808455024125 < x, x < oo))

# %%
solve(f)
# Out:
# [0.0, -2.73665153048207 + 0.e-20*I, -0.0125221286700732 + 0.e-20*I, 2.65808455024125 - 0.e-23*I]

# %%
from sympy import *
from sympy.plotting import plot
init_printing(use_unicode=False, wrap_line=False,no_global=True)
a5 ,a4, a3, a1, a2, a0 = symbols('a1, a2, a0, a3, a4, a5')
eq1_lp= -243*a5 + 81*a4 - 27*a3 + 9*a2 - 3*a1 + a0 - 33
eq2_lp=-32*a5 + 16*a4 - 8*a3 + 4*a2 - 2*a1 + a0 - 31
eq3_lp=-a5 + a4 - a3 + a2 - a1 + a0 - 18
eq4_lp=a5 + a4 + a3 + a2 + a1 + a0 + 18
eq5_lp=32*a5 + 16*a4 + 8*a3 + 4*a2 + 2*a1 + a0 + 31
eq6_lp=243*a5 + 81*a4 + 27*a3 + 9*a2 + 3*a1 + a0 + 33

# %%
nonlinsolve([eq1_lp, eq2_lp, eq3_lp, eq4_lp, eq5_lp, eq6_lp], [a5,a4,a3,a2,a1,a0])
# Out:
#             19
# {(1/120, 0, --, 0, -94/5, 0)}
#             24

# %%
f= (1/120)*x**5  + (19/24)*x**3  - (94/5)*x
f
# Out:
#                      5                      3
# 0.00833333333333333*x  + 0.791666666666667*x  - 18.8*x

# %%
f.subs(x,-3)
# Out:
# 33.0000000000000

# %%
f.subs(x,-2)
# Out:
# 31.0000000000000

# %%
f.subs(x,-1)
# Out:
# 18.0000000000000

# %%
f.subs(x,1)
# Out:
# -18.0000000000000

# %%
f.subs(x,2)
# Out:
# -31.0000000000000

# %%
f.subs(x,3)
# Out:
# -33.0000000000000

# %%
f.subs(x,10)
# Out:
# 1437.00000000000

# %%
f.subs(x,-10)
# Out:
# -1437.00000000000

# %%
solve(f)
# Out:
# [-4.43545751638198, 0.0, 4.43545751638198, -10.7085612189327*I, 10.7085612189327*I]

# %%
solve_univariate_inequality(f>0,x)
# Out:
# Or(And(-4.43545751638198 < x, x < 0), And(4.43545751638198 < x, x < oo))

# %%
solve_univariate_inequality(f<0,x)
# Out:
# Or(And(-oo < x, x < -4.43545751638198), And(0 < x, x < 4.43545751638198))

# %%
import numpy as np
import matplotlib.pyplot as plt

x_range = np.linspace(-5,5, num=100)
f= lambda x: (1/120)*x**5  + (19/24)*x**3  - (94/5)*x
plt.scatter([-3,-2,-1,1,2,3],[33,31,18,-18,-31,-33],c='r')
plt.axhline(0, color='black')
plt.axvline(0,color='black')
plt.plot(x_range,f(x_range))

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
points_X = [-3,-2,-1,1,2,3]
points_Y = [33,31,18,-18,-31,-33]

X = np.arange(-5, 5, 0.01)
Y = [(1/120)*x**5  + (19/24)*x**3  - (94/5)*x for x in X]

plt.scatter(points_X, points_Y, c='r')
plt.plot(X, Y, 'b')
plt.show()

# %% [markdown]
# # 5.2

# %%
points_X = [2,4,8]
points_Y = [12.258,17.24,30.151]

X = np.arange(-5, 10, 0.01)
Y = [3*x + 5 for x in X]

plt.scatter(points_X, points_Y, c='r')
plt.plot(X, Y, 'b')
plt.show()

# %%
from sklearn.metrics import mean_squared_error

# %%
y_true=[12.258,17.24,30.151]
y_pred=[11,17,29]
mean_squared_error(y_true,y_pred)
# Out:
# 0.9883216666666655

# %%
f = 3*x + 5 
f.subs(x,8)
# Out:
# 29

# %%
points_X = [2,4,8]
points_Y = [3.688,10.791,20.705]

X = np.arange(-5, 10, 0.01)
Y = [0.25*x**2 + 0.75*x + 1.25 for x in X]

plt.scatter(points_X, points_Y, c='r')
plt.plot(X, Y, 'b')
plt.show()

# %%
y_true=[3.688,10.791,20.705]
y_pred=[3.75,8.25,23.25]
mean_squared_error(y_true,y_pred)
# Out:
# 4.31251666666667

# %%
f = 0.25*x**2 + 0.75*x + 1.25
f.subs(x,8)

# %%
points_X = [2,4,8,10,12]
points_Y = [4.872,29.707,246.971, 485.727, 840.658]

X = np.arange(-5, 13, 0.01)
Y = [0.5*x**3 - 0.25*x**2 + 0.75*x + 1.25 for x in X]

plt.scatter(points_X, points_Y, c='r')
plt.plot(X, Y, 'b')
plt.show()

# %%
f = 0.5*x**3 - 0.25*x**2 + 0.75*x + 1.25
f.subs(x,12)
# Out:
# 838.250000000000

# %%
y_true=[4.872,29.707,246.971, 485.727, 840.658]

y_pred=[5.75,32.25,247.25,483.75,838.25]
mean_squared_error(y_true,y_pred)
# Out:
# 3.404513399999994

# %%
#5.3

# %%
from sympy import *
from sympy.plotting import plot
init_printing(use_unicode=False, wrap_line=False, no_global=True)

# %%
def print_points_ands_function(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([-3, -2, -1, 1, 2, 3])
    points_Y = np.array([15.0, 8.0, 13.0, 10.0, 15.0, 30.0])
    plt.xlim(-25, 7.5)
    plt.ylim(-1, 40)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

# %%
x = Symbol('x')
f = x ** 2 + 32 * x + 265
f
# Out:
#  2
# x  + 32*x + 265

# %%
print_points_ands_function(f)
# Out:
# MSE = 68981.16666666667

# %%
f_new=f.subs(x,x-20)

# %%
f_new
# Out:
#                2
# 32*x + (x - 20)  - 375

# %%
print_points_ands_function(f_new)
# Out:
# MSE = 687.8333333333334

# %%
expand(f_new)
# Out:
#  2
# x  - 8*x + 25

# %%
f_new_2=f_new.subs(x,x+5)
f_new_2
# Out:
#                2
# 32*x + (x - 15)  - 215

# %%
expand(f_new_2)
# Out:
#  2
# x  + 2*x + 10

# %%
print_points_ands_function(f_new_2)
# Out:
# MSE = 11.166666666666666

# %%
#5.3 HW Преобразования функций Сдвиги вправо и влево - Практика

# %%
from sympy import *
from sympy.plotting import plot
init_printing(use_unicode=False, wrap_line=False, no_global=True)

# %%
import matplotlib.pyplot as plt
import numpy as np
x=Symbol('x')

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([-3, -2, -1, 1, 2, 3])
    points_Y = np.array([60, 30, 19, -16, -37, -23])
    plt.xlim(-15, 15)
    plt.ylim(-40, 80)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

# %%
x = Symbol('x')
f1 = - 14 * x - 100
f1
# Out:
# -14*x - 100

# %%
print_points_ands_function1(f1)
# Out:
# MSE = 11233.166666666666

# %%
f1_new=f1.subs(x,x-7.5)
f1_new
# Out:
# 5.0 - 14*x

# %%
print_points_ands_function1(f1_new)
# Out:
# MSE = 103.16666666666667

# %%
def print_points_ands_function2(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([-3, -2, -1, 1, 2, 3])
    points_Y = np.array([-55, -40, 7, 5, 38, 53])
    plt.xlim(-5, 25)
    plt.ylim(-70, 70)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

# %%
f2 = 2 * x**3 - 121 * x**2 + 2443 * x - 16455
f2
# Out:
#    3        2
# 2*x  - 121*x  + 2443*x - 16455

# %%
print_points_ands_function2(f2)
# Out:
# MSE = 317653781.0

# %%
f2_new=f2.subs(x,x+20)
f2_new
# Out:
#                    3               2
# 2443*x + 2*(x + 20)  - 121*(x + 20)  + 32405

# %%
print_points_ands_function2(f2_new)
# Out:
# MSE = 141.0

# %%
#5.4

# %%
import matplotlib.pyplot as plt
import numpy as np

def print_points_ands_function3(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([-5, -4, -3, -2, -1, 1, 2, 3, 4, 5])
    points_Y = np.array([23, 19, 5, 7, 3, 2, 9, 19, 8, 22])
    plt.xlim(-15, 15)
    plt.ylim(-5, 40)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

# %%
x = Symbol('x')
f = x**2 / 3
f
# Out:
#  2
# x
# --
# 3

# %%
print_points_ands_function3(f)
# Out:
# MSE = 95.65555555555554

# %%
#прижимаем к oy
f_new=f.subs(x,x*2)
expand(f_new)
# Out:
#    2
# 4*x
# ----
#  3

# %%
print_points_ands_function3(f_new)
# Out:
# MSE = 53.58888888888889

# %%
f_new2=f_new.subs(x,x*1.3)
expand(f_new2)
# Out:
#                   2
# 2.25333333333333*x

# %%
print_points_ands_function3(f_new2/2.2)
# Out:
# MSE = 24.777494949494947

# %%
#приближаем(отдаляем) к ox - растяниваем к оси х
print_points_ands_function3(f*2)
# Out:
# MSE = 38.12222222222222

# %%
print_points_ands_function3((f*6)/2)
# Out:
# MSE = 24.1

# %%
#5.4 HW

# %%
from sympy import *
from sympy.plotting import plot
init_printing(use_unicode=False, wrap_line=False, no_global=True)

import matplotlib.pyplot as plt
import numpy as np

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([-2, -1, 0, 1, 2, 3, 3.5, 4, 4.5, 5])
    points_Y = np.array([-15, -1, 4, -9, -2, -5, -8, 4, 13, 21])
    plt.xlim(-10, 10)
    plt.ylim(-20, 20)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

# %%
f1 = 3.375 * x ** 3 - 9 * x**2
f1
# Out:
#        3      2
# 3.375*x  - 9*x

# %%
print_points_ands_function1(f1)
# Out:
# MSE = 5270.741845703125

# %%
f1_new=f1.subs(x,x/1.5)
print_points_ands_function1(f1_new)
# Out:
# MSE = 24.478125000000002

# %%
print_points_ands_function1(f1*1.5)
# Out:
# MSE = 12741.56680908203

# %%
def print_points_ands_function2(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([-3, -2, -1, 1, 2, 3])
    points_Y = np.array([-55, -40, 7, 5, 38, 53])
    plt.xlim(-10, 10)
    plt.ylim(-70, 70)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

# %%
f2 = 0.074 * x**3 - 0.11 * x**2 + x + 5
f2

print_points_ands_function2(f2)
# Out:
# MSE = 1262.7619146666668

# %%
f2_new=f2.subs(x,x*3)

# %%
print_points_ands_function2(f2_new/1.1)
# Out:
# MSE = 139.51035151515154

# %%
#5.6 HW

# %%
#С помощью symPy найдите полиномы, описывающие данные наборы точек. Затем проведите полное исследование каждого полученного полинома: проверьте четность/нечетность, найдите нули, промежутки знакопостоянства. Постройте их графики. С помощью изменения промежутка для х добейтесь того, чтобы все нули были отображены на графике функции. <br><br><br>
#а) $(-4; -4268), (-3; -1227), (-1; -17), (1; 17), (3; 1227), (4; 4268)
#б)$ (-4; -16729), (-3; -3999), (-1; 5), (1; 1), (3; 4005), (4; 16735)

# %%
from sympy import *

a0, a1, a2, a3, a4, a5 = symbols('a0, a1, a2, a3, a4, a5')

# %%
from sympy.plotting import plot
init_printing(use_unicode=False, wrap_line=False,no_global=True)

eq1_lp= (-4)**5*a5 + (-4)**4*a4 + (-4)**3*a3 + (-4)**2*a2 + (-4)*a1 + a0 + 4268
eq2_lp= (-3)**5*a5 + (-3)**4*a4 + (-3)**3*a3 + (-3)**2*a2 + (-3)*a1 + a0 + 1227
eq3_lp= (-1)**5*a5 + (-1)**4*a4 + (-1)**3*a3 + (-1)**2*a2 + (-1)*a1 + a0 + 17
eq4_lp=a5 + a4 + a3 + a2 + a1 + a0 - 17
eq5_lp= (3)**5*a5 + (3)**4*a4 + (3)**3*a3 + (3)**2*a2 + (3)*a1 + a0 - 1227
eq6_lp= (4)**5*a5 + (4)**4*a4 + (4)**3*a3 + (4)**2*a2 + (4)*a1 + a0 - 4268

# %%
nonlinsolve([eq1_lp, eq2_lp,eq3_lp,eq4_lp,eq5_lp,eq6_lp], [a5,a4,a3,a2,a1,a0])
# Out:
# {(3, 0, 19, 0, -5, 0)}

# %%
f1= 3*x**5 + 19*x**3 - 5*x
f1
# Out:
#    5       3
# 3*x  + 19*x  - 5*x

# %%
f1.subs(x,4)
#нечетная
# Out:
# 4268

# %%
f1.subs(x,-4)
# Out:
# -4268

# %%
solve(f1)
# Out:
#             ______________         ______________        ________________       ________________
#            /        _____         /        _____        /          _____       /          _____
#           /  19   \/ 421         /  19   \/ 421        /    19   \/ 421       /    19   \/ 421
# [0, -I*  /   -- + ------- , I*  /   -- + ------- , -  /   - -- + ------- ,   /   - -- + ------- ]
#        \/    6       6        \/    6       6       \/      6       6      \/      6       6

# %%
import numpy as np
import matplotlib.pyplot as plt

x_range = np.linspace(-6,7, num=100)
f= lambda x: 3*x**5 + 19*x**3 - 5*x
plt.scatter([-4,-3,-1,1,3,4],[-4268,-1227,-17,17,1227,4268],c='r')
plt.axhline(0, color='black')
plt.axvline(0,color='black')
plt.plot(x_range,f(x_range))

# %%
solve_univariate_inequality(f1>0,x)
# Out:
#   /   /             ________________    \     /             ________________    \\
#   |   |            /          _____     |     |            /          _____     ||
#   |   |           /    19   \/ 421      |     |           /    19   \/ 421      ||
# Or|And|x < 0, -  /   - -- + -------  < x|, And|x < oo,   /   - -- + -------  < x||
#   \   \        \/      6       6        /     \        \/      6       6        //

# %%
solve_univariate_inequality(f1>0,x)
# Out:
#   /   /             ________________    \     /             ________________    \\
#   |   |            /          _____     |     |            /          _____     ||
#   |   |           /    19   \/ 421      |     |           /    19   \/ 421      ||
# Or|And|x < 0, -  /   - -- + -------  < x|, And|x < oo,   /   - -- + -------  < x||
#   \   \        \/      6       6        /     \        \/      6       6        //

# %%
#
from sympy import *

a0, a1, a2, a3, a4, a5 = symbols('a0, a1, a2, a3, a4, a5')
(-4; -16729), (-3; -3999), (-1; 5), (1; 1), (3; 4005), (4; 16735)

# %%
from sympy.plotting import plot
init_printing(use_unicode=False, wrap_line=False,no_global=True)

eq1_lp= (-4)**5*a5 + (-4)**4*a4 + (-4)**3*a3 + (-4)**2*a2 + (-4)*a1 + a0 + 16729
eq2_lp= (-3)**5*a5 + (-3)**4*a4 + (-3)**3*a3 + (-3)**2*a2 + (-3)*a1 + a0 + 3999
eq3_lp= (-1)**5*a5 + (-1)**4*a4 + (-1)**3*a3 + (-1)**2*a2 + (-1)*a1 + a0 - 5
eq4_lp=a5 + a4 + a3 + a2 + a1 + a0 - 1
eq5_lp= (3)**5*a5 + (3)**4*a4 + (3)**3*a3 + (3)**2*a2 + (3)*a1 + a0 - 4005
eq6_lp= (4)**5*a5 + (4)**4*a4 + (4)**3*a3 + (4)**2*a2 + (4)*a1 + a0 - 16735

# %%
nonlinsolve([eq1_lp, eq2_lp,eq3_lp,eq4_lp,eq5_lp,eq6_lp], [a5,a4,a3,a2,a1,a0])
# Out:
# {(16, 0, 7, 0, -25, 3)}

# %%
f2 = 16*x**5 + 7*x**3 - 25*x + 3
f2
# Out:
#     5      3
# 16*x  + 7*x  - 25*x + 3

# %%
solve(f2)
# Out:
#         /    5      3              \         /    5      3              \         /    5      3              \         /    5      3              \         /    5      3              \
# [CRootOf\16*x  + 7*x  - 25*x + 3, 0/, CRootOf\16*x  + 7*x  - 25*x + 3, 1/, CRootOf\16*x  + 7*x  - 25*x + 3, 2/, CRootOf\16*x  + 7*x  - 25*x + 3, 3/, CRootOf\16*x  + 7*x  - 25*x + 3, 4/]

# %%
f2.subs(x,-4)
# Out:
# -16729

# %%
f2.subs(x,4)
# Out:
# 16735

# %%
import numpy as np
import matplotlib.pyplot as plt

x_range = np.linspace(-6,6, num=100)
f= lambda x: 16*x**5 + 7*x**3 - 25*x + 3
plt.scatter([-4,-3,-1,1,3,4],[-16729,-3999,5,1,4005,16735],c='r')
plt.axhline(0, color='black')
plt.axvline(0,color='black')
plt.plot(x_range,f(x_range))

# %%
#1
from sympy import *
from sympy.plotting import plot
init_printing(use_unicode=False, wrap_line=False, no_global=True)

import matplotlib.pyplot as plt
import numpy as np

x = Symbol('x')

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([-2, -1, 0, 1, 2, 3, 3.5, 4, 4.5, 5])
    points_Y = np.array([2, -4, 1, 8, 21, 40, 47, 65, 75, 92])
    plt.xlim(-6, 10)
    plt.ylim(-1, 100)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

f1 = 48 * x**2 - 128 * x + 83
f1

print_points_ands_function1(f1)
# Out:
# MSE = 93691.3

# %%
f1_new=f1.subs(x,x+1.5)
f1_new_1=f1_new.subs(x,x/4.04)
print_points_ands_function1(f1_new_1)
# Out:
# MSE = 4.061924528812855

# %%
#2
def print_points_ands_function2(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([-2, -1, 0, 1, 2, 3, 3.5, 4, 4.5, 5])
    points_Y = np.array([-31, -9, 4, -1, 9, 24, 47, 92, 120, 170])
    plt.xlim(-3, 6)
    plt.ylim(-35, 200)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

f2 = 4 * x**3 + 30 * x**2 + 74 * x + 62
f2
print_points_ands_function2(f2)
# Out:
# MSE = 607200.2

# %%
f2_new=f2.subs(x,x-3)
f2_new_1=f2_new.subs(x,x/1.1)
print_points_ands_function2(f2_new_1/1.5)
# Out:
# MSE = 21.98184614836542

# %%
#3
def print_points_ands_function3(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([-2, -1, 0, 1, 2, 3, 3.5, 4, 4.5, 5])
    points_Y = np.array([60, 25, 4, -0, -57, -195, -295, -540, -700, -760])
    plt.xlim(-10, 6)
    plt.ylim(-850, 100)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

f3 = -36 * x**3 - 756 * x**2 - 5334 * x - 12636
f3

print_points_ands_function3(f3)
# Out:
# MSE = 1346344545.35

# %%
f3_new=f3.subs(x,x-7)
f3_new_1=f3_new.subs(x,x/1.7)
print_points_ands_function3(f3_new_1/1.2)
# Out:
# MSE = 2292.0048026791765

# %%
#4

# %%
def print_points_ands_function4(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([-2, -1, 0, 1, 2, 3, 3.5, 4, 4.5, 5])
    points_Y = np.array([-42, -37, -23, -36, -45, -80, -83, -110, -131, -155])
    plt.xlim(-4, 20)
    plt.ylim(-160, -10)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

f4 = - 5 / 4 * x**2 + 25 * x - 152
f4

print_points_ands_function4(f4)
# Out:
# MSE = 9143.51953125

# %%
f4_new=f4.subs(x,x+10)
f4_new_1=expand(f4_new.subs(x,x*2))
f4_new_1
print_points_ands_function4(f4_new_1)
# Out:
# MSE = 20.3125

# %%
f4_new_1
# Out:
#        2
# - 5.0*x  - 27.0

# %%
#6.2 HW В качестве практики к данному уроку найдите промежутки возрастания и убывания нескольких функций с помощью
#их производных (производные даны). Найдите, при каких значениях аргумента достигаются максимум и минимум как
#значения, при которых возрастание сменяется убыванием и наоборот. Постройте графики этих функций. Соответствуют
#ли полученные с помощью производных результаты графикам? Неравенства для производных можно решать и вручную, и с 
#помощью sympy, решите сами, как вам удобнее. А можете решать вручную и затем проверять себя.

# %%
f1= x**2 + 3*x -4 
f1_d=diff(f1)

# %%
f1.subs(x,-3/2)
# Out:
# -6.25000000000000

# %%
solve_univariate_inequality(f1_d>0,x) #промежутки >0 и <0
# Out:
# And(-3/2 < x, x < oo)

# %%
solve(f1_d) # нули функции
# Out:
# [-3/2]

# %%
plot(f1)

# %%
f2 = x**3 - 2*x**2 + x - 6
f2_d=diff(f2)
f2_d
# Out:
#    2
# 3*x  - 4*x + 1

# %%
solve(diff(f2))
# Out:
# [1/3, 1]

# %%
solve_univariate_inequality(f2_d>0,x)
# Out:
# Or(And(-oo < x, x < 1/3), And(1 < x, x < oo))

# %%
solve_univariate_inequality(f2_d<0,x)
# Out:
# And(1/3 < x, x < 1)

# %%
plot(f2_d, (x, -1, 2))

# %%
import numpy as np
import matplotlib.pyplot as plt

x_range = np.linspace(-3,3, num=100)
f2= lambda x: x**3 - 2*x**2 + x - 6

plt.axhline(0, color='black')
plt.axvline(0,color='black')
plt.plot(x_range,f2(x_range))

# %%
f3 = exp(2*x - x**2)
f3_d=diff(f3)
f3_d
# Out:
#               2
#            - x  + 2*x
# (2 - 2*x)*e

# %%
solve(f3_d)
# Out:
# [1]

# %%
solve_univariate_inequality(f3_d<0,x)
# Out:
# And(1 < x, x < oo)

# %%
solve_univariate_inequality(f3_d>0,x)
# Out:
# And(-oo < x, x < 1)

# %%
plot(f3)

# %%
#6.4

# %%
f1=5*x**2
f1_d=diff(5*x**2)
f1_d
# Out:
# 10*x

# %%
f2=3*sin(x)
f2_d=diff(f2)
f2_d
# Out:
# 3*cos(x)

# %%
f3=2/3*exp(x)
f3_d=diff(f3)
f3_d
# Out:
#                    x
# 0.666666666666667*e

# %%
f4=5*x**2 + 3*sin(x)
f4_d=diff(f4)
f4_d
# Out:
# 10*x + 3*cos(x)

# %%
f5 = 7*x**3 + 3*x - 4
f5_d=diff(f5)
f5_d
# Out:
#     2
# 21*x  + 3

# %%
f6 = 13*exp(x) + 3*x**2 - 4*sin(x)
f6_d=diff(f6)
f6_d
# Out:
#           x
# 6*x + 13*e  - 4*cos(x)

# %%
#6.6

# %%
f1=5*x**5 + 7*x
# 25*x**4 + 7
diff(f1)
# Out:
#     4
# 25*x  + 7

# %%
f2=6*x**4 + 12*x**2 +5
# 24*x**3 + 24*x 
diff(f2)
# Out:
#     3
# 24*x  + 24*x

# %%
f3=6*x**3 + 3*x**4 - 4
#18*x**2 + 12*x**3
diff(f3)
# Out:
#     3       2
# 12*x  + 18*x

# %%
f4=(2*x+3)*(6*x+2)
# 24*x+22
diff(f4)
# Out:
# 24*x + 22

# %%
f5=(3*x**2 + exp(x))*sin(x)
diff(f5)
# Out:
# /       x\          /   2    x\
# \6*x + e /*sin(x) + \3*x  + e /*cos(x)

# %%
f6=3*sin^2(x)
# Out:
# <>:1: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# <ipython-input-833-b45143962dd1>:1: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
#   f6=3*sin^2(x)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-833-b45143962dd1> in <module>
# ----> 1 f6=3*sin^2(x)
#
# TypeError: unsupported operand type(s) for *: 'int' and 'FunctionClass'

# %%
f7=13*exp(2*x) + 5*x**7
#
diff(f7)
# Out:
#     6       2*x
# 35*x  + 26*e

# %%
#6.8 сигмоидная функция 1/1+exp(-x) логистическая функция логистическая регрессия

# %%
f = 1/1+exp(-x)
diff(f)
# Out:
#   -x
# -e

# %%
#6.9HW

# %%
f1 = 6**x + 3*x**3 +5
diff(f1)
# Out:
#  x             2
# 6 *log(6) + 9*x

# %%
f2 = 5*x*exp(x)
diff(f2)
# Out:
#      x      x
# 5*x*e  + 5*e

# %%
f3 = pi**x + 2*sin(x)
diff(f3)
# Out:
#   x
# pi *log(pi) + 2*cos(x)

# %%
f4 = x**2/sin(x)
diff(f4)
# Out:
#    2
#   x *cos(x)    2*x
# - --------- + ------
#       2       sin(x)
#    sin (x)

# %%
f5 = exp(2*x)
diff(f5)
# Out:
#    2*x
# 2*e

# %%
diff(pi**x)
# Out:
#   x
# pi *log(pi)

# %%
f6 = 5*x**3/exp(3*x)
diff(f6)
# Out:
#       3  -3*x       2  -3*x
# - 15*x *e     + 15*x *e

# %%
f7 = 2*((5/2-x)**2)
diff(f7)
# Out:
# 4.0*x - 10.0

# %%
f8 = exp(x**2)
diff(f8)
# Out:
#      / 2\
#      \x /
# 2*x*e

# %%
f9 = 5**(7*x**3 + 5)
diff(f9)
# Out:
#        3
#     7*x  + 5  2
# 21*5        *x *log(5)

# %%
f10 = sin(3*x**5 + exp(2*x))
diff(f10)
# Out:
# /    4      2*x\    /   5    2*x\
# \15*x  + 2*e   /*cos\3*x  + e   /

# %%
#7.3 Графики функций двух переменных

# %%
from sympy import *
from sympy.plotting import plot3d
init_printing(use_unicode=False, wrap_line=False, no_global=True)

# %%
x,y,z=symbols('x y z')

# %%
f = 0.8*x + 20*y 
f
# Out:
# 0.8*x + 20*y

# %%
plot3d(f)

# %%
f = x * y / sqrt(x**2 + y**2 - 5)

# %%
plot3d(f)

# %%
solve(f)
# Out:
# [{x: 0}, {y: 0}]

# %%
#7.3HW

# %%
f1 = sin(sqrt(x**2 + y**2))
plot3d(f1)

# %%
f2 = exp(-0.9*x**2 - 0.45*((x-y))**2)
plot3d(f2,(x,-3,3),(y,-3,3))

# %%
f3 = x*cos(y)
plot3d(f3)

# %%
#7.4

# %%
f = x - y + 1
plot3d(f)

# %%
f = 5*x - 3*y +2
solve(f)
# Out:
#      3*y   2
# [{x: --- - -}]
#       5    5

# %%
plot3d(f)

# %%
funk_x=3/5*y - 2/5
plot(funk_x)

# %%
f1 = x * y / sqrt(x**2 + y**2 - 5)
solve(f1)
# Out:
# [{x: 0}, {y: 0}]

# %%
#7.4

# %%
f1 = 2*x + 5*y + 1

# %%
solve(f1)
# Out:
#        5*y   1
# [{x: - --- - -}]
#         2    2

# %%
plot3d(f1)

# %%
funk_x = -(5*y)/2 - 1/2 #прямая, по которой плоскость пересекает xy
plot(funk_x)

# %%
f2 = x**2 + y**2 - 1
solve(f2)
# Out:
#          ________          ________
#         /      2          /      2
# [{x: -\/  1 - y  }, {x: \/  1 - y  }]

# %%
plot3d(f2)

# %%
func_x2= -sqrt(1 - y**2)

plot(func_x2,(y, -1,1))

# %%
func_x2= sqrt(1 - y**2)

plot(func_x2,(y, -1,1))

# %%
f3 = x*cos(y)
solve(f3)
# Out:
#              pi       3*pi
# [{x: 0}, {y: --}, {y: ----}]
#              2         2

# %%
f3 = x * cos(y)
plot3d(f3)

# %%
#Гиперплоскость - подпространство, заданное функцией внутри пространства

# %%
#7.7HW

# %%
from sympy import *
from sympy.plotting import plot
init_printing(use_unicode=False, wrap_line=False, no_global=True)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = Symbol('x')

# %%
#1

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([-2, -1, 0, 1, 2, 3, 3.5, 4, 4.5, 5])
    points_Y = np.array([3, 1, -0.5, 1.2, 2.5, 0.8, -2, -3.5, -3, -5])
    plt.xlim(-10, 10)
    plt.ylim(-8, 5)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

# %%
f1 = 2 * x * sin(2 * x + 5) + 5 * sin(2 * x + 5) + 2
f1
# Out:
# 2*x*sin(2*x + 5) + 5*sin(2*x + 5) + 2

# %%
print_points_ands_function1(f1)
# Out:
# MSE = 90.56454338961888

# %%
f1 = 2 * x * sin(2 * x + 5) + 5 * sin(2 * x + 10) +2
f_f1 = f1.subs(x, 0.616 * x + 0.523) * 0.4389 - 0.5678
#f_f1 = f1.subs(x, 5.823 * x - 4.1997) * 0.09097 - 0.03367
print_points_ands_function1(f_f1)
# Out:
# MSE = 1.2850657223161475

# %%
def print_points_ands_function2(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([0, 1, 2, 3, 3.5, 4, 4.5, 5, 6, 6.5, 7, 8, 9])
    points_Y = np.array([0.5, 1.2, 0.7, 1.2, 1.1, 0.7, 0.65, 0.9, 0.95, 0.3, 0.8, 0.5, 0.0])
    plt.xlim(-1, 20)
    plt.ylim(-2, 2)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0] + 1, plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

# %%
f2 = sin(sqrt(3) *sqrt(x)) - 1
f2
# Out:
#    /  ___   ___\
# sin\\/ 3 *\/ x / - 1

# %%
print_points_ands_function2(f2)
# Out:
# MSE = 4.609003555572037

# %%
f2 = sin(sqrt(3) *sqrt(x)) + 1
f2
f_f2 = f2.subs(x,(x)/2)
print_points_ands_function2(f_f2/2)
# Out:
# MSE = 0.05594713832841222

# %%
#Постройте графики функций 2 переменных. Найдите их нули и затем постройте графики их нулей,
#если они не представляют собой выражения вида {x: ...}. <br>

# %%
f1=x*y**2

# %%
plot3d(f1)

# %%
solve(f1)
# Out:
# [{x: 0}, {y: 0}]

# %%
f2= (y-exp(1)/20)**2*sin(pi*x)
f2
# Out:
#         2
# /    E \
# |y - --| *sin(pi*x)
# \    20/

# %%
plot3d(f2)

# %%
plot3d(f2)

# %%
solve(f2)
# Out:
# [{x: 0}, {x: 1}, {y: 0}]

# %%
f3=x*sin(x)*sin(y)
plot3d(f3)

# %%
solve(f3)
# Out:
# [{x: 0}, {x: pi}, {y: 0}, {y: pi}]

# %%
#3.1

# %%
#{0,1,...}x{0,1}x{0,1,...}x{0,1,..}

# %%
#3.2

# %%
#{0,1, ..}x{0,1,..}x{0,1}

# %%
#3.3

# %%
#{0,1}x{35...40}x{0,1}x{0,1}

# %%
f = (y-exp(1)/20)**2*sin(pi*x)

# %%
#8.2

# %%
from sympy import *
from sympy.plotting import plot3d
init_printing(use_unicode=False, wrap_line=False, no_global=True)

# %%
a2, a1, a0 = symbols('a2, a1, a0')

# %%
MSE = 1/3 * (((a2 * 2 + a1 * 200 + a0) - 200)**2 + \
             ((a2 * 1 + a1 * 450 + a0) - 300)**2 + \
             ((a2 * 3 + a1 * 550 + a0) - 600)**2)
MSE
# Out:
#                                             2                                             2                                               2
# 0.333333333333333*(a0 + 200*a1 + 2*a2 - 200)  + 0.333333333333333*(a0 + 450*a1 + a2 - 300)  + 0.333333333333333*(a0 + 550*a1 + 3*a2 - 600)

# %%
#{a2: 1, a1: 2, a0: 3}
# f1 = 100 * x2 - 1 * x1 - 100
# f2 = 200 * x2 + 3 * x1 + 20

# %%
MSE.subs({a2: 100, a1: -1, a0: -100})
# Out:
# 518333.333333333

# %%
MSE.subs({a2: 200, a1: 3, a0: 20})
# Out:
# 1691400.00000000

# %%
#8.2HW

# %%
#    1. Объекты: (10, 30), (-5, 15), (16, 31). 
#    Целевые значения: 7, 20, -4.
#    Функции-кандидаты:

# %%
MSE = 1/3*(((10 * a2 + 30 * a1 + a0) - 7 )**2 +  ((-5*a2 + 15 * a1 + a0) - 20)**2 + ((16*a2 + 31 * a1 + a0) + 4)**2)
MSE
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1c69ffaf8a9e> in <module>
# ----> 1 MSE = 1/3*(((10 * a2 + 30 * a1 + a0) - 7 )**2 +  ((-5*a2 + 15 * a1 + a0) - 20)**2 + ((16*a2 + 31 * a1 + a0) + 4)**2)
#       2 MSE
#
# NameError: name 'a2' is not defined

# %%
MSE.subs({a2: (-2),a1:1,a0:-7})
# Out:
# 36

# %%
MSE.subs({a2: (20),a1:3,a0:-4})
# Out:
# 254651

# %%
MSE_1 = ((16 * a2 + 17 * a1 + a0) - 13 )**2 +  ((-3*a2 + 28 * a1 + a0) - 42)**2 + ((14*a2 + 85 * a1 + a0) - 39)**2
MSE_1
# Out:
#                          2                           2                            2
# (a0 + 17*a1 + 16*a2 - 13)  + (a0 + 28*a1 - 3*a2 - 42)  + (a0 + 85*a1 + 14*a2 - 39)

# %%
MSE_1.subs({a2: (-2),a1:-1,a0:60})
# Out:
# 8484

# %%
MSE_1.subs({a2: (2),a1:17,a0:-9})
# Out:
# 2295587

# %%
MSE_2 = ((7 * a2 + 39 * a1 + a0) + 60 )**2 +  ((12*a2 + 48 * a1 + a0) - 17)**2 + ((3*a2 + 55 * a1 + a0) - 83)**2
MSE_2
# Out:
#                         2                            2                           2
# (a0 + 39*a1 + 7*a2 + 60)  + (a0 + 48*a1 + 12*a2 - 17)  + (a0 + 55*a1 + 3*a2 - 83)

# %%
MSE_2.subs({a2: (-4),a1:7,a0:-11})
# Out:
# 231877

# %%
MSE_2.subs({a2: (-0.5),a1:9,a0:-400})
# Out:
# 247.500000000000

# %%
#8.3 HW

# %%
x1,x2,x3=symbols('x1 x2 x3')

# %%
f1 = 10*x1 - 5*x2
#f_diff(x1)= 10 , f_diff(x2) = -5
print(diff(f1,x1), diff(f1,x2))
# Out:
# 10 -5

# %%
f2 = 3*x1 + 4*x2 + 7
#f_diff(x1 = 3) f_diff(x2) = 4
print(diff(f2,x1), diff(f2,x2))
# Out:
# 3 4

# %%
f3 = x1**2
#f3_diff = 2*x1
diff(f3)
# Out:
# 2*x1

# %%
f4 = x1 + 5*x2 - 6*x3 + 3
#f4_diff(x1) = 1, f4_diff(x2) = 5 f4_diff(x3) = -6
print(diff(f4,x1), diff(f4,x2), diff(f4,x3))
# Out:
# 1 5 -6

# %%
f5 = 10*x1 - x2**2 + 4*x3**3
print(diff(f5,x1), diff(f5,x2), diff(f5,x3))
# Out:
# 10 -2*x2 12*x3**2

# %%
f6 = x1**2 + 12*x1*x2 +4*x2**3 + x3 
print(diff(f6,x1), diff(f6,x2), diff(f6,x3))
# Out:
# 2*x1 + 12*x2 12*x1 + 12*x2**2 1

# %%
#8.4

# %%
MSE = 1/3 * (((a2 * 2 + a1 * 200 + a0) - 200)**2 + \
             ((a2 * 1 + a1 * 450 + a0) - 300)**2 + \
             ((a2 * 3 + a1 * 550 + a0) - 600)**2)
MSE
# Out:
#                                             2                                             2                                               2
# 0.333333333333333*(a0 + 200*a1 + 2*a2 - 200)  + 0.333333333333333*(a0 + 450*a1 + a2 - 300)  + 0.333333333333333*(a0 + 550*a1 + 3*a2 - 600)

# %%
diff(MSE,a2)
# Out:
# 733.333333333333*a0 + 1666.66666666667*a1 + 326666.666666667*a2 - 336666.666666667

# %%
diff(MSE,a0)
# Out:
# 2.0*a0 + 4.0*a1 + 733.333333333333*a2 - 800.0

# %%
MSEa2 = 1/3 * (28 * a2 + 5000 * a1 + 12 * a0 - 5000)
MSEa1 = 1/3 * (5000 * a2 + 1090000 * a1 + 2400 * a0 - 1010000)
MSEa0 = 1/3 * (12 * a2 + 2400 * a1 + 6 * a0 - 2200)

# %%
nonlinsolve([MSEa2, MSEa1, MSEa0], [a2, a1, a0])
# Out:
# {(108.333333333333, 0.833333333333333, -183.333333333334)}

# %%
MSE.subs({a2: 108.333333333333, a1: 0.833333333333333, a0: -183.333333333334})
# Out:
# 2.19558210646898e-24

# %%
x2, x1 = symbols('x2, x1')
f = 325 / 3 * x2 + 2.5 / 3 * x1 - 550 / 3 
f
# Out:
# 0.833333333333333*x1 + 108.333333333333*x2 - 183.333333333333

# %%
f.subs({'x1': 500, 'x2': 4})
# Out:
# 666.666666666667

# %%
#8.5 HW

# %%
MSE = 1/3* ((200*a2 + 2*a1 + a0 - 200)**2 + \
           (300*a2 + a1 + a0 - 450)**2 + \
           (600*a2 + 3*a1 + a0 - 550)**2)
MSE
# Out:
#                                           2                                               2                                               2
# 0.333333333333333*(a0 + a1 + 300*a2 - 450)  + 0.333333333333333*(a0 + 2*a1 + 200*a2 - 200)  + 0.333333333333333*(a0 + 3*a1 + 600*a2 - 550)

# %%
MSEa2 = 1/3 * (980000 * a2 + 5000 * a1 + 2200 * a0 - 1010000)
MSEa1 = 1/3 * (5000 * a2 + 28 * a1 + 12 * a0 - 5000)
MSEa0 = 1/3 * (2200 * a2 + 12 * a1 + 6 * a0 - 2400)

# %%
nonlinsolve([MSEa2, MSEa1, MSEa0], [a2, a1, a0])
# Out:
# {(1.2, -130.0, 220.0)}

# %%
MSE.subs({a2: 1.2, a1: -130, a0: 220})
# Out:
# 0

# %%
f = 1.2*x2 - 130*x1 + 220
f
# Out:
# -130*x1 + 1.2*x2 + 220

# %%
f.subs({'x1': 4, 'x2': 666})
# Out:
# 499.200000000000

# %%
MSE_diff_a2 = diff(MSE,a2)
MSE_diff_a2
# Out:
# 733.333333333333*a0 + 1666.66666666667*a1 + 326666.666666667*a2 - 336666.666666667

# %%
MSE_diff_a1 = diff(MSE,a1)
MSE_diff_a1
# Out:
# 4.0*a0 + 9.33333333333333*a1 + 1666.66666666667*a2 - 1666.66666666667

# %%
MSE_diff_a0 =diff(MSE,a0)
MSE_diff_a0
# Out:
# 2.0*a0 + 4.0*a1 + 733.333333333333*a2 - 800.0

# %%
nonlinsolve([MSE_diff_a2,MSE_diff_a1,MSE_diff_a0],[a2,a1,a0])
# Out:
# {(1.2, -130.0, 220.0)}

# %%
MSE.subs({a2: 1.2, a1: -130.0, a0: -220.0})
# Out:
# 193600.000000000

# %%
f = 1.2*x2 - 130*x1 + 220
f
# Out:
# -130*x1 + 1.2*x2 + 220

# %%
f.subs({'x1':666,'x2':4})
# Out:
# -86355.2000000000

# %%
#8.6

# %%
from sympy import *

# %%
x = Symbol('x')

# %%
#гиперболический тангенс

# %%
th = (exp(x) - exp(-x)) / (exp(x) + exp(-x))
th
# Out:
#  x    -x
# e  - e
# --------
#  x    -x
# e  + e

# %%
diff(th)
# Out:
# /   x    -x\ / x    -x\
# \- e  + e  /*\e  - e  /
# ----------------------- + 1
#                 2
#       / x    -x\
#       \e  + e  /

# %%
tanh(x)
# Out:
# tanh(x)

# %%
diff(tanh(x))
# Out:
#         2
# 1 - tanh (x)

# %%
a2, a1, a0 = symbols('a2, a1, a0')

# %%
MSE = 1/3 * (((a2 * 2 + a1 * 200 + a0) - 200)**2 + \
             ((a2 * 1 + a1 * 450 + a0) - 300)**2 + \
             ((a2 * 3 + a1 * 550 + a0) - 600)**2)
MSE
# Out:
#                                             2                                             2                                               2
# 0.333333333333333*(a0 + 200*a1 + 2*a2 - 200)  + 0.333333333333333*(a0 + 450*a1 + a2 - 300)  + 0.333333333333333*(a0 + 550*a1 + 3*a2 - 600)

# %%
MSEa2 = 1/3 * (28 * a2 + 5000 * a1 + 12 * a0 - 5000)
MSEa1 = 1/3 * (5000 * a2 + 1090000 * a1 + 2400 * a0 - 1010000)
MSEa0 = 1/3 * (12 * a2 + 2400 * a1 + 6 * a0 - 2200)

# %%
#8.7 HW

# %%
#1.a

# %%
x,y = symbols('x y')
f1 = x*(y-5)**2
diff(f1,x)
# Out:
#        2
# (y - 5)

# %%
print(diff(f1,x), diff(f1,y))
# Out:
# (y - 5)**2 x*(2*y - 10)

# %%
#1.b

# %%
f2 = ((y*(exp(1)/20))**2)*sin(pi*x)
f2
# Out:
#  2  2
# y *e *sin(pi*x)
# ---------------
#       400

# %%
print(diff(f2,x), diff(f2,y))
# Out:
# pi*y**2*exp(2)*cos(pi*x)/400 y*exp(2)*sin(pi*x)/200

# %%
f3 = x*sin(x)*sin(y-2)
f3
# Out:
# x*sin(x)*sin(y - 2)

# %%
print(diff(f3,x), diff(f3,y))
# Out:
# x*sin(y - 2)*cos(x) + sin(x)*sin(y - 2) x*sin(x)*cos(y - 2)

# %%
#2

# %%
MSE = 1/3* ((560 * a2 + 1945*a1 + a0 - 4.3)**2 + \
            (340 * a2 + 1495*a1 + a0 - 4.9)**2 + \
            (343 * a2 + 1570*a1 + a0 - 5.2)**2)
MSE
# Out:
#                                                            2                                                              2                                                             2
#                  / a0         112*a2                      \                     / a0         343*a2                      \                     / a0         68*a2                      \
# 1261008.33333333*|---- + a1 + ------ - 0.00221079691516709|  + 821633.333333333*|---- + a1 + ------ - 0.00331210191082803|  + 745008.333333333*|---- + a1 + ----- - 0.00327759197324415|
#                  \1945         389                        /                     \1570         1570                       /                     \1495         299                       /

# %%
MSE_diff_a2 = diff(MSE,a2)
MSE_diff_a1 = diff(MSE,a1)
MSE_diff_a0 = diff(MSE,a0)
print(MSE_diff_a2,MSE_diff_a1,MSE_diff_a0)
# Out:
# 828.666666666667*a0 + 1424006.66666667*a1 + 364566.0*a2 - 3905.06666666667 3340.0*a0 + 5655300.0*a1 + 1424006.66666667*a2 - 15902.0 2.0*a0 + 3340.0*a1 + 828.666666666667*a2 - 9.6

# %%
nonlinsolve([MSE_diff_a2,MSE_diff_a1,MSE_diff_a0],[a2,a1,a0])
# Out:
# {(-0.0118811881188066, 0.00447524752474972, 2.24910891089351)}

# %%
MSE.subs({a2:-0.0118811881188066, a1:0.00447524752474972,a0:2.24910891089351})
# Out:
# 6.19066832333820e-27

# %%
f = -0.0118811881188066*x2 +  0.00447524752474972*x1 + 2.24910891089351
f
# Out:
# 0.00447524752474972*x1 - 0.0118811881188066*x2 + 2.24910891089351

# %%
f.subs({x2:431,x1:1520})
# Out:
# 3.93069306930744

# %%
#9.2

# %%
from sympy import *
init_printing(use_unicode=True)
Matrix([[1,2,3,4]]) + Matrix([[5,6,7,8]])
# Out:
# [6  8  10  12]

# %%
Matrix([[1,2,3,4]]) + Matrix([[10,11,12,13]])
# Out:
# [11  13  15  17]

# %%
Matrix([[15],[16],[17],[18],[19]]) + Matrix([[3],[3],[3],[3],[3]])
# Out:
# ⎡18⎤
# ⎢  ⎥
# ⎢19⎥
# ⎢  ⎥
# ⎢20⎥
# ⎢  ⎥
# ⎢21⎥
# ⎢  ⎥
# ⎣22⎦

# %%
5* Matrix([[1,2,3,4,5,6]]) - 3* Matrix([[5,6,7,8,9,10]])
# Out:
# [-10  -8  -6  -4  -2  0]

# %%
12* Matrix([[7,12,11,14,9,16]]) - 3.2* Matrix([[13,61,24,76,1,3]])
# Out:
# [42.4  -51.2  55.2  -75.2  104.8  182.4]

# %%
7 * Matrix([[15],[16],[17],[18],[19]]) + 1/3*Matrix([[3],[3],[3],[3],[3]])
# Out:
# ⎡106.0⎤
# ⎢     ⎥
# ⎢113.0⎥
# ⎢     ⎥
# ⎢120.0⎥
# ⎢     ⎥
# ⎢127.0⎥
# ⎢     ⎥
# ⎣134.0⎦

# %%
7 * Matrix([[11],[21],[78],[32],[2]]) + 2/5*Matrix([[5],[6],[7],[9],[3]])
# Out:
# ⎡79.0 ⎤
# ⎢     ⎥
# ⎢149.4⎥
# ⎢     ⎥
# ⎢548.8⎥
# ⎢     ⎥
# ⎢227.6⎥
# ⎢     ⎥
# ⎣15.2 ⎦
